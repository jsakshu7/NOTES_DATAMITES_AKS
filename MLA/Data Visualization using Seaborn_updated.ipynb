# %% [markdown]
# # Data Visulaization using Seaborn.

# %% [markdown]
# Seaborn is a library that uses Matplotlib underneath to plot graphs.
# Graphs that show the relationship between two variables-Bivariate Graphs
# Graphs that represent the distribution of a single variable.Univariate Graphs

# %%
# importing the required libraries
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
#!pip install seaborn --upgrade

# %%
# getting the built-in datasets of seaborn.
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
# loading dataset
df= sns.load_dataset("iris")

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.species.unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
df.species.value_counts()
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# # lineplot()

# %%
sns.lineplot(x='sepal_length', y='sepal_width', data=df, errorbar=None) #Confidence interval errorbar=('ci', 70)
plt.show()

# %% [raw]
# Confidence intervals provide us with a way to estimate a population parameter. Rather than say that the parameter is equal to an exact value, we say that the parameter falls within a range of values.

# %% [raw]
# sns.lineplot(...): Creates a line plot.
# x='sepal_length', y='sepal_width': Specifies the columns in df (a DataFrame) to use for the x- and y-axes.
# data=df: Indicates the data source.
# ci=None: Disables the confidence interval shading (default is 95% CI).
# plt.show(): Displays the plot.

# %%
### Line plot
sns.lineplot(x='sepal_length', y='sepal_width', data=df,hue='species', errorbar=None)
plt.show()

# %% [raw]
# Setosa may show higher sepal width at shorter sepal lengths — indicating a broader sepal for smaller flowers.
#
# Versicolor and Virginica may have more gradual or different slopes, possibly showing less width variation or different growth trends.
#
# Differences in line slope and height across species can reveal biological distinctions — like how one species tends to have longer but narrower sepals.
#
# If the lines are relatively smooth and not noisy, this suggests a linear relationship between sepal_length and sepal_width within each species.
# A flat line means little to no relationship.
# A steeper slope indicates stronger correlation between length and width.

# %%
# continuous and categorical feature
sns.lineplot(x='sepal_length', y='species', data=df, hue='species', errorbar=None)
print(df.groupby('species')['sepal_length'].min())
plt.show()
# Out:
# species
# setosa        4.3
# versicolor    4.9
# virginica     4.9
# Name: sepal_length, dtype: float64

# %% [markdown]
# Most of virginic has sepal length greater than 7 units.
# Versicolor can be found in range 5.5 units to 7 units
# Setosa can be found in 4.3 to 5.5 units
# If sepal length of flower is greater than 4.3 units than only
# flower can be iris flower.

# %%
sns.lineplot(x='petal_length', y='species',hue='species', data=df, errorbar=None)
plt.show()

# %% [markdown]
# # Scatter PLot

# %%
## Scatter plot--distribution and relationships.
sns.scatterplot(x='sepal_length',y='sepal_width',data=df)
plt.title("Scatter plot")
plt.show()

# %%
sns.scatterplot(x='sepal_length',y='sepal_width',data=df, hue='species')
plt.title("Scatter plot")
plt.show()

# %% [markdown]
# - Species Separation
# You’ll likely see that Setosa clusters in a separate region (shorter and wider sepals).
# Versicolor and Virginica may overlap more, but show different trends.
# - correlation between sepal_length and sepal_width for each species.
# A downward or upward slope suggests a trend.
# Scatter spread shows variability within each group.
# - Outliers or Anomalies
# Points far away from the main cluster might be outliers or unusual observations.

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# Bar PLot

# %%
## Bar plot (categorical estimate plot)
##A barplot is basically used to aggregate the categorical data according to some methods and by default its the mean.
##It can also be understood as a visualization of the group by action.
#To use this plot we choose a categorical column for
##the x axis and a numerical column for the y axis and we see that it
# creates a plot taking a mean per categorical column.

sns.barplot(x='species', y='sepal_length', data=df,estimator=np.min,errorbar=None)
plt.show()

# %%
## Count Plot  value_count()
##A countplot basically counts the categories and returns a
# count of their occurrences.
sns.countplot(x='species', data=df)
plt.show()

# %%
df.species.value_counts()
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # Box Plot

# %%
## Box plot
##A boxplot is sometimes known as the box and whisker plot.It shows the
#distribution of the quantitative data
## that represents the comparisons between variables. boxplot shows the
#quartiles of the dataset while the whiskers extend to
## show the rest of the distribution i.e. the dots indicating the
#presence  of outliers.
sns.boxplot(x='sepal_width',data=df)
plt.show()

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# A box plot (also called a whisker plot) summarizes the distribution of a numerical variable:
#
# Box: 25th percentile (Q1) to 75th percentile (Q3) → the interquartile range (IQR).
#
# Line inside box: Median (50th percentile).
#
# Whiskers: Extend to ~1.5 × IQR beyond Q1 and Q3.
#
# Dots outside whiskers: Outliers.

# %%
sns.boxplot(x='species', y='sepal_width', data=df)
plt.show()
# Checking outliers in each category with respect to sepal width.

# %% [markdown]
# ## Violinplot

# %%
## Violinplot
## It is similar to the boxplot except that it provides a higher, more advanced visualization and uses the kernel
##density estimation to give a better description about the data distribution.

sns.violinplot(x='species', y='sepal_width', data=df)
plt.show()

# %% [raw]
# Distribution Shape per Species
# Wider parts of the violin = more data points in that sepal width range.
#
# Setosa typically shows a higher sepal width and a narrower distribution (less spread).
#
# Versicolor and Virginica may have more overlapping distributions but different central tendencies.
#
# 2. Median and Spread
# Look for the thick white dot or line inside the violin: that's the median.
#
# You can visually compare how spread out or skewed each species' sepal width is.
#
# 3. Skew or Multi-modality
# If the violin is asymmetrical or has multiple bumps, it might suggest skew or multiple subgroups.

# %%
##Stripplot

# %%
##Stripplot
## It basically creates a scatter plot based on the category.
# It is created using the stripplot()
sns.stripplot(x='species', y='petal_width', data=df)
plt.show()

# %% [markdown]
# ## 1. Raw Data Visibility
# Unlike box or violin plots, this plot shows **every individual data point**.
#
# Great for spotting:
# - **Outliers**
# - **Gaps or clusters**
# - **Duplicates or tightly packed values**
#
# ---
#
# ## 2. Species-Level Differences
# - **Setosa**: Most values clustered tightly around **0.2 cm**, showing very little variation.
# - **Versicolor**: Ranges between **1.0 – 1.8 cm**, with moderate spread.
# - **Virginica**: Widest spread, going up to **2.5 cm**, indicating greater variation.
#
# ---

# %%
## Histogram
## A histogram is basically used to represent data provided in a form of some groups.
## It is accurate method for the graphical representation of numerical data
## distribution
sns.histplot(x='petal_width', data=df,kde=True) # The data is divided into 5 equal-width intervals


plt.show()

# %%
sns.histplot(x='petal_width', data=df,hue='species', kde=True,bins=10) # kernel density estimation
plt.show()
#kde is approximation of histogram to density curve.

# %%
import warnings
warnings.filterwarnings('ignore')
## Distplot
## Distplot is used basically for univariant set of observations
# and visualizes it through a histogram
## i.e. only one observation and hence we choose one particular column of the dataset
sns.distplot(df['petal_width'],color="g") # ,hist=False, kde=False
plt.show()
## density means the probability of given point to lie on the curve.

# %%
##Pairplot
##Pairplot represents pairwise relation across the entire dataframe and supports an

## additional  argument called hue for categorical separation.
#What it does basically is create a jointplot between every possible numerical
##column and takes a while if the dataframe is really huge

sns.pairplot(data=df, hue='species')
plt.show()

# %%
# categorical plot
sns.catplot(x='sepal_length', data=df, kind="violin")
plt.show()          # Options: "strip", "swarm", "box", "violin", "bar", "count", "point"

# %%
sns.catplot(x='petal_length',y='species',data=df)
plt.show()

# %% [markdown]
# | plot     | Description                      | Use Case Example                  |
# | -------- | -------------------------------- | --------------------------------- |
# | `strip`  | Scatter of all observations      | Distribution of scores            |
# | `swarm`  | Like `strip`, but avoids overlap | Compact view of individual points |
# | `box`    | Boxplot with quartiles           | Visualizing spread and outliers   |
# | `violin` | Combines KDE + boxplot           | Distribution + density            |
# | `bar`    | Shows mean + CI                  | Comparing group averages          |
# | `count`  | Barplot of count of observations | Frequency of categories           |
# | `point`  | Shows means + CI with line       | Trends over time or ordered vars  |

# %% [markdown]
# Correlation studies and measures the direction and extent of relationship among variables
# correlation summarize the relationship between two variables in a single number called the correlation coefficient. The correlation coefficient is usually represented using the symbol r, and it ranges from -1 to +1.
#
# A correlation coefficient quite close to 0, but either positive or negative, implies little or no relationship between the two variables. A correlation coefficient close to plus 1 means a positive relationship between the two variables, with increases in one of the variables being associated with increases in the other variable.
#
# A correlation coefficient close to -1 indicates a negative relationship between two variables, with an increase in one of the variables being associated with a decrease in the other variable.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
sns.heatmap(df.drop("species",axis=1).corr(),annot=True)
# Out:
# <Axes: >

# %%
##Heat map
## Heatmap is defined as a graphical representation of data using colors to visualize the value of the matrix.
## In this, to represent more common values or higher activities brighter colors basically reddish colors are used and
## to represent less common or activity values, darker colors are preferred

# correlation between the different parameters
sns.heatmap(df.corr(numeric_only=True), annot=True)#, cmap='coolwarm', fmt=".2f")

#Very strong linear relationship — as petal length increases, petal width also increases.
# Out:
# <Axes: >

# %%
sns.barplot(x='species', y='petal_length', data=df,estimator=np.mean)
plt.show()
